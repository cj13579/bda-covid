# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

window_size=7

# %%
df = pd.read_csv('csv/positivity_rate.csv')
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Positivity Rate  7 day rolling average
# 58  2021-05-14         0.422833               0.358801

# %%
df = pd.read_csv('csv/active_cases.csv')
df['Cases per 100k'] = (df['7 day rolling average']/72086)*100000
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Active Cases  7 day rolling average
# 69  2021-05-11           242             338.142857

# %%
df = pd.read_csv('csv/positive_cases.csv')
df['Cases per 100k'] = (df['7 day rolling average']/72086)*100000
df = df.round(decimals=0)
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Positive Cases  7 day rolling average  Cases per 100k
# 58  2021-05-14               4                    5.0             7.0
