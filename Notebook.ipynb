# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

window_size=7

# %%
df = pd.read_csv('csv/positivity_rate.csv')
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Positivity Rate  7 day rolling average
# 55  2021-05-11         0.566572               0.549366

# %%
df = pd.read_csv('csv/active_cases.csv')
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Active Cases  7 day rolling average
# 69  2021-05-11           242             338.142857

# %%
df = pd.read_csv('csv/positive_cases.csv')
df.set_index('date')
df.plot(x='date')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.iloc[[-1]]
# Out:
#           date  Positive Cases  7 day rolling average
# 55  2021-05-11               4               8.857143
